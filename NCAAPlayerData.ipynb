# %%
# Complete pipeline with:
# - Cross-division de-dup of games (SEEN_GIDS)
# - Correct team division via team→division votes (TEAM_TRUE_DIV)
# - Boxscore player stats incl. GK Saves/GA
# - PBP-derived Fouls Won (merged PER GAME)
# - Team-scoped fuzzy name matching for merges
# - FIX: Do NOT group by Dominant Position; compute it ONCE at the end
#        from all positions seen across games (mode with tie-break)

import warnings
warnings.filterwarnings('ignore')

import time
import json
import os
import re
from collections import defaultdict, Counter

import requests
import pandas as pd
from unidecode import unidecode
from rapidfuzz import process, fuzz


# ====================
# Config
# ====================
START_DATE = '2025-08-14'
END_DATE   = '2025-09-02'
GENDERS    = ['men', 'women']
DIVISIONS  = ['d1', 'd2', 'd3']

UA = ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
      "(KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")
REQ_HEADERS = {"User-Agent": UA, "Accept": "application/json,text/*,*/*;q=0.9", "Connection": "keep-alive"}

SESSION = requests.Session()
SESSION.headers.update(REQ_HEADERS)


# ====================
# Name utilities
# ====================
def preprocess_name(name):
    """Lowercase, strip, de-accent. Robust to NaN/non-strings."""
    if pd.isna(name):
        return ""
    return unidecode(str(name)).strip().lower()

def clean_name(name):
    """Title-cased, de-accented, and swaps 'Last, First' → 'First Last'."""
    if not name:
        return ""
    s = str(name)
    if ', ' in s:
        s = ' '.join(s.split(', ')[::-1])
    return unidecode(s).strip().title()

def create_name_mapping(*name_lists, similarity_threshold=90):
    """Map preprocessed names to canonical tokens using fuzzy matching."""
    all_tokens = set()
    for names in name_lists:
        all_tokens.update(preprocess_name(n) for n in names if n is not None)
    standardized = {}
    for token in list(all_tokens):
        if not standardized:
            standardized[token] = token
            continue
        match = process.extractOne(token, list(standardized.keys()), scorer=fuzz.WRatio)
        if match and match[1] > similarity_threshold:
            standardized[token] = standardized[match[0]]
        else:
            standardized[token] = token
    return standardized

def apply_name_mapping(names, name_mapping):
    return [name_mapping.get(preprocess_name(n), preprocess_name(n)) for n in names]


# ====================
# Position helpers
# ====================
def dominant_position_single(pos):
    """Map a single raw position string to a coarse label."""
    if pd.isna(pos) or not isinstance(pos, str) or len(pos) == 0:
        return "Unknown"
    position_keywords = {
        'Midfielder': ['M', 'MIDFIELDER'],
        'Defender'  : ['D', 'DEFENDER'],
        'Forward'   : ['F', 'FORWARD'],
        'Goalkeeper': ['G', 'GK', 'GOALKEEPER']
    }
    up = pos.upper()
    counts = {lab: sum(up.count(k) for k in keys) for lab, keys in position_keywords.items()}
    if all(v == 0 for v in counts.values()):
        return "Unknown"
    return max(counts, key=counts.get)

POS_TIEBREAK = {'Goalkeeper': 0, 'Defender': 1, 'Midfielder': 2, 'Forward': 3, 'Unknown': 9}

def compute_dominant_position_over_games(positions_series: pd.Series) -> str:
    """Choose the most frequent coarse label across all games; break ties by POS_TIEBREAK."""
    if positions_series is None or positions_series.empty:
        return "Unknown"
    labels = positions_series.map(dominant_position_single)
    if labels.empty:
        return "Unknown"
    counts = labels.value_counts(dropna=False)
    max_count = counts.max()
    candidates = [lab for lab, cnt in counts.items() if cnt == max_count]
    return sorted(candidates, key=lambda lab: POS_TIEBREAK.get(lab, 9))[0]


# ====================
# Scoreboard (game ids + teams) & votes for team→division
# ====================
def get_day_games(gender: str, day_mmdd: str, division: str):
    """Return list of {'gid': str, 'teams': [{'id': str, 'shortName': str}, ...]} for a day/division."""
    month, day = day_mmdd.split("/")
    url = f"https://data.ncaa.com/casablanca/scoreboard/soccer-{gender}/{division}/2025/{month}/{day}/scoreboard.json"
    out = []
    try:
        r = SESSION.get(url, timeout=20)
        r.raise_for_status()
        data = r.json()
        for g in data.get("games", []) or []:
            game_url = (g.get("game", {}) or {}).get("url", "")
            gid = game_url.strip("/").split("/")[-1] if game_url else ""
            teams = []
            for t in g.get("teams", []) or []:
                tid = str(t.get("id") or t.get("teamId") or "").strip()
                short = (t.get("shortName") or t.get("seoName") or t.get("nickName") or "").strip()
                if tid:
                    teams.append({"id": tid, "shortName": short})
            if gid:
                out.append({"gid": gid, "teams": teams})
    except Exception as e:
        print(f"Error fetching day games: {e} ({gender} {division} {day_mmdd})")
    return out


# ====================
# Boxscore → per-player rows (incl. GK stats); adds Game ID, Team ID
# ====================
def _first_present(d, keys, default=0):
    for k in keys:
        if k in d and d[k] not in (None, "", "NA"):
            try:
                return int(float(str(d[k])))
            except Exception:
                pass
    return default

def clean_data_from_boxscore_payload(data, gid):
    # meta teams (for team names)
    home_id = str(data['meta']['teams'][0]['id'])
    away_id = str(data['meta']['teams'][1]['id'])
    home_nm = data['meta']['teams'][0].get('shortName', '')
    away_nm = data['meta']['teams'][1].get('shortName', '')

    def _team_name_for(team_id_str):
        return home_nm if team_id_str == home_id else (away_nm if team_id_str == away_id else "")

    out = []
    for team in data.get('teams', []) or []:
        tid = str(team.get('teamId', '')).strip()
        team_name = _team_name_for(tid)
        if not team_name:
            continue

        # GK lookup
        gk_by_name = {}
        for g in team.get('goalieStats', []) or []:
            raw_name = g.get('name') or f"{g.get('firstName','')} {g.get('lastName','')}"
            name = clean_name(raw_name)
            gk_by_name[name] = {
                'Saves': _first_present(g, ['saves'], 0),
                'Goals Against': _first_present(g, ['goalsAllowed','goalsAgainst','ga'], 0),
                'Minutes GK': _first_present(g, ['minutesAtGoalie','minutes'], 0),
                'Jersey': str(g.get('jerseyNum','')).strip(),
            }

        # Fallback: goalieTotals + exactly one GK in playerStats
        if not gk_by_name:
            gt = team.get('goalieTotals') or {}
            tot_saves = _first_present(gt, ['saves'], 0)
            tot_ga    = _first_present(gt, ['goalsAllowed','goalsAgainst','ga'], 0)
            gk_players = [p for p in (team.get('playerStats', []) or [])
                          if dominant_position_single((p.get('position') or '').strip()) == 'Goalkeeper']
            if len(gk_players) == 1:
                p0 = gk_players[0]
                name0 = clean_name(f"{p0.get('firstName','')} {p0.get('lastName','')}".strip())
                gk_by_name[name0] = {
                    'Saves': tot_saves,
                    'Goals Against': tot_ga,
                    'Minutes GK': _first_present(p0, ['minutesPlayed','minutes'], 0),
                    'Jersey': str(p0.get('jerseyNum','')).strip(),
                }

        # Emit player rows
        for p in team.get('playerStats', []) or []:
            full_name = clean_name(f"{p.get('firstName','')} {p.get('lastName','')}".strip())
            pos   = (p.get('position') or '').strip()

            row = {
                'Game ID': gid,
                'Team ID': tid,
                'Name': full_name,
                'Team': team_name,
                'Position': pos,  # keep raw; do NOT compute dominant here
                'Matches Played': 1 if _first_present(p, ['minutesPlayed','minutes'], 0) > 0 else 0,
                'Minutes Played': _first_present(p, ['minutesPlayed','minutes'], 0),
                'Goals': _first_present(p, ['goals'], 0),
                'Assists': _first_present(p, ['assists'], 0),
                'Shots': _first_present(p, ['shots'], 0),
                'Shots On Target': _first_present(p, ['shotsOnGoal','shotsOnTarget'], 0),
                'Yellow Cards': _first_present(p, ['yellowCards'], 0),
                'Red Cards': _first_present(p, ['redCards'], 0),
                'Saves': 0,
                'Goals Against': 0,
            }
            if full_name in gk_by_name:
                row['Saves'] = gk_by_name[full_name]['Saves']
                row['Goals Against'] = gk_by_name[full_name]['Goals Against']
            out.append(row)

    return out

def collect_players_from_games(game_ids):
    players_all = []
    for gid in game_ids:
        url = f"https://data.ncaa.com/casablanca/game/{gid}/boxscore.json"
        data = None

        try:
            r = SESSION.get(url, headers={"Referer": f"https://www.ncaa.com/game/{gid}"}, timeout=20)
            if r.status_code == 200:
                data = r.json()
        except requests.RequestException:
            data = None

        if data is None:
            try:
                result = os.popen(
                    f'curl -s -H "User-Agent: {UA}" -H "Referer: https://www.ncaa.com/game/{gid}" {url}'
                ).read()
                data = json.loads(result)
            except Exception:
                data = None

        if not data or 'meta' not in data or 'teams' not in data:
            continue

        players_all.extend(clean_data_from_boxscore_payload(data, gid))
        time.sleep(0.1)
    return players_all


# ====================
# PBP → Fouls Won (PER GAME)
# ====================
def extract_player(event):
    pattern = r'\b[A-Z][a-z]+,?\s*[A-Z][a-z]+'
    matches = re.findall(pattern, event or "")
    return matches[0] if matches else None

def categorize_event(event):
    if not event:
        return 'Other'
    if 'Goal by' in event:
        return 'Goal'
    elif 'Shot by' in event:
        return 'Shot'
    elif 'Foul on' in event or 'Foul' in event:
        return 'Foul'
    elif 'Corner kick' in event:
        return 'Corner Kick'
    elif 'Offside' in event:
        return 'Offside'
    else:
        return 'Other'

def collect_fouls_won(game_ids):
    foul_data = []
    for game_id in game_ids:
        data = None
        try:
            response = SESSION.get(f'https://data.ncaa.com/casablanca/game/{game_id}/pbp.json', timeout=20)
            response.raise_for_status()
            data = response.json()
        except requests.exceptions.RequestException as e:
            print(f"Error fetching PBP via requests for game {game_id}: {e}")
            try:
                result = os.popen(
                    f'curl -s https://data.ncaa.com/casablanca/game/{game_id}/pbp.json'
                ).read()
                data = json.loads(result)
            except Exception as e2:
                print(f"Error fetching PBP via curl for game {game_id}: {e2}")
                continue

        if not data or 'meta' not in data or 'periods' not in data:
            print(f"Invalid PBP for game {game_id}")
            continue

        home = data['meta']['teams'][0]['shortName']
        away = data['meta']['teams'][1]['shortName']

        events = []
        score = '0-0'
        for period in data.get('periods', []) or []:
            for play in period.get('playStats', []) or []:
                score = play.get('score') or score
                tm = play.get('time', '')
                if play.get('visitorText'):
                    team_side = 1
                    event = play.get('visitorText', '')
                else:
                    team_side = 0
                    event = play.get('homeText', '')
                events.append({'Score': score, 'Time': tm, 'Event': event, 'Team': team_side})

        if not events:
            continue

        df = pd.DataFrame(events)
        df['Name'] = df['Event'].apply(extract_player).map(clean_name)
        df['Event_Type'] = df['Event'].apply(categorize_event)
        df['Team'] = df['Team'].apply(lambda x: home if x == 0 else away)
        df['IsFoul'] = df['Event'].str.contains('Foul', case=False, na=False)

        foul_df = df[df['IsFoul'] & df['Name'].notna()].copy()
        if foul_df.empty:
            continue

        foul_summary = (foul_df.groupby(['Name', 'Team'])
                        .size().reset_index(name='Fouls'))
        foul_summary['Game ID'] = game_id  # per-game fouls
        foul_data.append(foul_summary)

    if foul_data:
        return pd.concat(foul_data, ignore_index=True)
    else:
        return pd.DataFrame(columns=['Game ID','Name','Team','Fouls'])


# ====================
# Pipeline
# ====================
date_range = pd.date_range(start=START_DATE, end=END_DATE, freq='D')
time_range = date_range.strftime('%m/%d').tolist()

SEEN_GIDS       = {'men': set(), 'women': set()}
TEAM_DIV_VOTES  = {'men': defaultdict(Counter), 'women': defaultdict(Counter)}
PROCESSED_GIDS  = set()

all_player_rows = []

for gender in GENDERS:
    for division in DIVISIONS:
        for day in time_range:
            day_games = get_day_games(gender, day, division)
            if not day_games:
                continue

            # team→division votes
            for g in day_games:
                for t in g['teams']:
                    TEAM_DIV_VOTES[gender][str(t['id'])][division] += 1

            # fetch each gid once per gender
            new_gids = [g['gid'] for g in day_games if g['gid'] not in SEEN_GIDS[gender]]
            if not new_gids:
                continue

            rows = collect_players_from_games(new_gids)
            if rows:
                df = pd.DataFrame(rows)
                df['Gender'] = gender
                df['Division'] = division  # temporary; will be overwritten by true division
                all_player_rows.append(df)

            SEEN_GIDS[gender].update(new_gids)
            PROCESSED_GIDS.update(new_gids)

# Combine & de-dup per (game/team/player/gender)
if all_player_rows:
    players_raw = pd.concat(all_player_rows, ignore_index=True)
    players_raw = players_raw.drop_duplicates(subset=['Game ID','Team ID','Name','Gender'])
else:
    players_raw = pd.DataFrame(columns=[
        'Game ID','Team ID','Name','Team','Position', 'Matches Played','Minutes Played','Goals','Assists','Shots','Shots On Target',
        'Yellow Cards','Red Cards','Saves','Goals Against','Gender','Division'
    ])

# True team division from votes (ties: d1 > d2 > d3)
ORDER = {'d1': 0, 'd2': 1, 'd3': 2}
TEAM_TRUE_DIV = {}
for gdr, bucket in TEAM_DIV_VOTES.items():
    for tid, counter in bucket.items():
        if counter:
            winners = sorted(counter.items(), key=lambda kv: (-kv[1], ORDER.get(kv[0], 9)))
            TEAM_TRUE_DIV[(gdr, str(tid))] = winners[0][0]

if not players_raw.empty:
    players_raw['Division'] = players_raw.apply(
        lambda r: TEAM_TRUE_DIV.get((r['Gender'], str(r['Team ID'])), r['Division']),
        axis=1
    )
    players_raw['Name'] = players_raw['Name'].map(clean_name)

# Merge Fouls Won (PER GAME) with team-scoped fuzzy matching
fouls_df = collect_fouls_won(list(PROCESSED_GIDS))
if not players_raw.empty and not fouls_df.empty:
    players_raw['NameKey'] = players_raw['Name'].fillna('').map(preprocess_name)
    fouls_df['Name']       = fouls_df['Name'].map(clean_name)
    fouls_df['NameKey']    = fouls_df['Name'].fillna('').map(preprocess_name)

    players_raw['NameKeyStd'] = players_raw['NameKey']
    fouls_df['NameKeyStd']    = fouls_df['NameKey']

    teams_union = sorted(set(players_raw['Team'].dropna().unique()).union(set(fouls_df['Team'].dropna().unique())))
    for team in teams_union:
        p_mask = players_raw['Team'] == team
        f_mask = fouls_df['Team'] == team
        p_names = players_raw.loc[p_mask, 'Name'].tolist()
        f_names = fouls_df.loc[f_mask, 'Name'].tolist()
        if not p_names and not f_names:
            continue
        name_map = create_name_mapping(p_names, f_names, similarity_threshold=90)
        players_raw.loc[p_mask, 'NameKeyStd'] = apply_name_mapping(p_names, name_map)
        fouls_df  .loc[f_mask, 'NameKeyStd'] = apply_name_mapping(f_names, name_map)

    players_raw = players_raw.merge(
        fouls_df[['Game ID','Team','NameKeyStd','Fouls']],
        on=['Game ID','Team','NameKeyStd'],
        how='left'
    )
    players_raw['Fouls Won'] = pd.to_numeric(players_raw['Fouls'], errors='coerce').fillna(0).astype(int)
    players_raw.drop(columns=['Fouls','NameKey','NameKeyStd'], errors='ignore', inplace=True)
else:
    players_raw['Fouls Won'] = 0

# ====================
# Aggregate WITHOUT Dominant Position in the key
# Then compute Dominant Position ONCE from all positions seen
# ====================
num_cols = [
    'Matches Played', 'Minutes Played','Goals','Assists','Shots','Shots On Target',
    'Yellow Cards','Red Cards','Saves','Goals Against','Fouls Won'
]
for c in num_cols:
    if c in players_raw.columns:
        players_raw[c] = pd.to_numeric(players_raw[c], errors='coerce').fillna(0)

key_cols = ['Name','Team','Gender','Division']

# Aggregate stats
player_stats = (players_raw
                .groupby(key_cols, as_index=False)[num_cols]
                .sum())

# Collect raw positions seen per player over all games (optional but useful)
positions_seen = (players_raw
                  .groupby(key_cols)['Position']
                  .apply(lambda s: ', '.join(sorted({str(x).strip() for x in s if pd.notna(x) and str(x).strip()})))
                  .reset_index(name='Positions Seen'))

player_stats = player_stats.merge(positions_seen, on=key_cols, how='left')

# Compute Dominant Position ONCE per player across games
dompos = (players_raw
          .groupby(key_cols)['Position']
          .apply(compute_dominant_position_over_games)
          .reset_index(name='Dominant Position'))

player_stats = player_stats.merge(dompos, on=key_cols, how='left')

# ====================
# Gender splits + GK views (now a single row per player)
# ====================
mens_df   = player_stats[player_stats['Gender'] == 'men'  ].reset_index(drop=True)
womens_df = player_stats[player_stats['Gender'] == 'women'].reset_index(drop=True)

gk_cols = ['Name','Team','Gender','Division','Dominant Position','Saves','Goals Against', 'Matches Played', 'Minutes Played',
           'Goals','Assists','Shots','Shots On Target','Yellow Cards','Red Cards','Fouls Won']

mens_gk_df = (mens_df[mens_df['Dominant Position'] == 'Goalkeeper']
              .loc[:, gk_cols]
              .reset_index(drop=True))

womens_gk_df = (womens_df[womens_df['Dominant Position'] == 'Goalkeeper']
                .loc[:, gk_cols]
                .reset_index(drop=True))

# Ensure ints for GK-specific stats
for _df in (mens_gk_df, womens_gk_df):
    for c in ('Saves','Goals Against','Fouls Won'):
        if c in _df.columns:
            _df[c] = pd.to_numeric(_df[c], errors='coerce').fillna(0).astype(int)

mens_df['Points'] = mens_df['Goals'] * 2 + mens_df['Assists']
womens_df['Points'] = womens_df['Goals'] * 2 + womens_df['Assists']

print(f"Built {len(mens_df)} men rows, {len(womens_df)} women rows")
print(f"GKs: {len(mens_gk_df)} men, {len(womens_gk_df)} women")
# Out:
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d1/2025/08/14/scoreboard.json (men d1 08/14)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d1/2025/08/15/scoreboard.json (men d1 08/15)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d1/2025/08/15/scoreboard.json (men d1 08/15)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d1/2025/08/20/scoreboard.json (men d1 08/20)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d1/2025/08/20/scoreboard.json (men d1 08/20)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d2/2025/08/14/scoreboard.json (men d2 08/14)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d2/2025/08/14/scoreboard.json (men d2 08/14)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d2/2025/08/17/scoreboard.json (men d2 08/17)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d2/2025/08/17/scoreboard.json (men d2 08/17)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d2/2025/08/19/scoreboard.json (men d2 08/19)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d2/2025/08/19/scoreboard.json (men d2 08/19)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d2/2025/09/01/scoreboard.json (men d2 09/01)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d2/2025/09/01/scoreboard.json (men d2 09/01)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d2/2025/09/02/scoreboard.json (men d2 09/02)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d2/2025/09/02/scoreboard.json (men d2 09/02)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d3/2025/08/14/scoreboard.json (men d3 08/14)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d3/2025/08/15/scoreboard.json (men d3 08/15)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d3/2025/08/14/scoreboard.json (men d3 08/14)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d3/2025/08/15/scoreboard.json (men d3 08/15)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d3/2025/08/16/scoreboard.json (men d3 08/16)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-men/d3/2025/08/16/scoreboard.json (men d3 08/16)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d2/2025/08/15/scoreboard.json (women d2 08/15)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d2/2025/08/15/scoreboard.json (women d2 08/15)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d2/2025/08/16/scoreboard.json (women d2 08/16)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d2/2025/08/17/scoreboard.json (women d2 08/17)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d2/2025/08/16/scoreboard.json (women d2 08/16)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d2/2025/08/17/scoreboard.json (women d2 08/17)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d2/2025/08/18/scoreboard.json (women d2 08/18)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d2/2025/08/18/scoreboard.json (women d2 08/18)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d2/2025/09/01/scoreboard.json (women d2 09/01)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d2/2025/09/01/scoreboard.json (women d2 09/01)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/14/scoreboard.json (women d3 08/14)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/15/scoreboard.json (women d3 08/15)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/14/scoreboard.json (women d3 08/14)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/15/scoreboard.json (women d3 08/15)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/16/scoreboard.json (women d3 08/16)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/16/scoreboard.json (women d3 08/16)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/17/scoreboard.json (women d3 08/17)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/18/scoreboard.json (women d3 08/18)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/17/scoreboard.json (women d3 08/17)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/18/scoreboard.json (women d3 08/18)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/19/scoreboard.json (women d3 08/19)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/19/scoreboard.json (women d3 08/19)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/29/scoreboard.json (women d3 08/29)
# Error fetching day games: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/scoreboard/soccer-women/d3/2025/08/29/scoreboard.json (women d3 08/29)
# Error fetching PBP via requests for game 6468399: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6468399/pbp.json
# Error fetching PBP via requests for game 6468399: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6468399/pbp.json
# Invalid PBP for game 6468399
# Invalid PBP for game 6468399
# Error fetching PBP via requests for game 6477992: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6477992/pbp.json
# Error fetching PBP via requests for game 6477992: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6477992/pbp.json
# Invalid PBP for game 6477992
# Invalid PBP for game 6477992
# Error fetching PBP via requests for game 6475757: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6475757/pbp.json
# Error fetching PBP via requests for game 6475757: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6475757/pbp.json
# Invalid PBP for game 6475757
# Invalid PBP for game 6475757
# Error fetching PBP via requests for game 6463043: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6463043/pbp.json
# Error fetching PBP via requests for game 6463043: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6463043/pbp.json
# Error fetching PBP via requests for game 6470480: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6470480/pbp.json
# Error fetching PBP via requests for game 6470480: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6470480/pbp.json
# Invalid PBP for game 6470480
# Invalid PBP for game 6470480
# Error fetching PBP via requests for game 6475174: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6475174/pbp.json
# Error fetching PBP via requests for game 6475174: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6475174/pbp.json
# Invalid PBP for game 6475174
# Invalid PBP for game 6475174
# Error fetching PBP via requests for game 6477174: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6477174/pbp.json
# Error fetching PBP via requests for game 6477174: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6477174/pbp.json
# Invalid PBP for game 6477174
# Invalid PBP for game 6477174
# Error fetching PBP via requests for game 6477674: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6477674/pbp.json
# Error fetching PBP via requests for game 6477674: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6477674/pbp.json
# Invalid PBP for game 6477674
# Invalid PBP for game 6477674
# Error fetching PBP via requests for game 6469359: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6469359/pbp.json
# Error fetching PBP via requests for game 6469359: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6469359/pbp.json
# Invalid PBP for game 6469359
# Invalid PBP for game 6469359
# Error fetching PBP via requests for game 6474234: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6474234/pbp.json
# Error fetching PBP via requests for game 6474234: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6474234/pbp.json
# Invalid PBP for game 6474234
# Invalid PBP for game 6474234
# Error fetching PBP via requests for game 6474044: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6474044/pbp.json
# Error fetching PBP via requests for game 6474044: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6474044/pbp.json
# Invalid PBP for game 6474044
# Invalid PBP for game 6474044
# Error fetching PBP via requests for game 6470836: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6470836/pbp.json
# Error fetching PBP via requests for game 6470836: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6470836/pbp.json
# Invalid PBP for game 6470836
# Invalid PBP for game 6470836
# Error fetching PBP via requests for game 6477071: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6477071/pbp.json
# Error fetching PBP via requests for game 6477071: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6477071/pbp.json
# Invalid PBP for game 6477071
# Invalid PBP for game 6477071
# Error fetching PBP via requests for game 6477154: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6477154/pbp.json
# Error fetching PBP via requests for game 6477154: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6477154/pbp.json
# Invalid PBP for game 6477154
# Invalid PBP for game 6477154
# Error fetching PBP via requests for game 6473980: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6473980/pbp.json
# Error fetching PBP via requests for game 6473980: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6473980/pbp.json
# Invalid PBP for game 6473980
# Invalid PBP for game 6473980
# Error fetching PBP via requests for game 6474925: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6474925/pbp.json
# Error fetching PBP via requests for game 6474925: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6474925/pbp.json
# Error fetching PBP via requests for game 6476625: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6476625/pbp.json
# Error fetching PBP via requests for game 6476625: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6476625/pbp.json
# Invalid PBP for game 6476625
# Invalid PBP for game 6476625
# Error fetching PBP via requests for game 6474553: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6474553/pbp.json
# Error fetching PBP via requests for game 6474553: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6474553/pbp.json
# Invalid PBP for game 6474553
# Invalid PBP for game 6474553
# Error fetching PBP via requests for game 6466298: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6466298/pbp.json
# Error fetching PBP via requests for game 6466298: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6466298/pbp.json
# Error fetching PBP via requests for game 6473605: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6473605/pbp.json
# Error fetching PBP via requests for game 6473605: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6473605/pbp.json
# Invalid PBP for game 6473605
# Invalid PBP for game 6473605
# Error fetching PBP via requests for game 6471319: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6471319/pbp.json
# Error fetching PBP via requests for game 6471319: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6471319/pbp.json
# Invalid PBP for game 6471319
# Invalid PBP for game 6471319
# Error fetching PBP via requests for game 6476783: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6476783/pbp.json
# Error fetching PBP via requests for game 6476783: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6476783/pbp.json
# Invalid PBP for game 6476783
# Invalid PBP for game 6476783
# Error fetching PBP via requests for game 6466548: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6466548/pbp.json
# Error fetching PBP via requests for game 6466548: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6466548/pbp.json
# Error fetching PBP via requests for game 6476129: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6476129/pbp.json
# Error fetching PBP via requests for game 6476129: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6476129/pbp.json
# Invalid PBP for game 6476129
# Invalid PBP for game 6476129
# Error fetching PBP via requests for game 6463573: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6463573/pbp.json
# Error fetching PBP via requests for game 6463573: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6463573/pbp.json
# Error fetching PBP via requests for game 6476318: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6476318/pbp.json
# Error fetching PBP via requests for game 6476318: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6476318/pbp.json
# Invalid PBP for game 6476318
# Invalid PBP for game 6476318
# Error fetching PBP via requests for game 6465597: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6465597/pbp.json
# Error fetching PBP via requests for game 6465597: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6465597/pbp.json
# Invalid PBP for game 6465597
# Invalid PBP for game 6465597
# Error fetching PBP via requests for game 6477199: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6477199/pbp.json
# Error fetching PBP via requests for game 6477199: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6477199/pbp.json
# Invalid PBP for game 6477199
# Error fetching PBP via requests for game 6466149: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6466149/pbp.json
# Invalid PBP for game 6477199
# Error fetching PBP via requests for game 6466149: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6466149/pbp.json
# Error fetching PBP via requests for game 6467330: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6467330/pbp.json
# Error fetching PBP via requests for game 6467330: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6467330/pbp.json
# Invalid PBP for game 6467330
# Invalid PBP for game 6467330
# Error fetching PBP via requests for game 6463063: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6463063/pbp.json
# Error fetching PBP via requests for game 6463063: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6463063/pbp.json
# Invalid PBP for game 6463063
# Invalid PBP for game 6463063
# Error fetching PBP via requests for game 6466705: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6466705/pbp.json
# Error fetching PBP via requests for game 6466705: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6466705/pbp.json
# Invalid PBP for game 6466705
# Invalid PBP for game 6466705
# Error fetching PBP via requests for game 6478000: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6478000/pbp.json
# Error fetching PBP via requests for game 6478000: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6478000/pbp.json
# Invalid PBP for game 6478000
# Invalid PBP for game 6478000
# Error fetching PBP via requests for game 6478599: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6478599/pbp.json
# Error fetching PBP via requests for game 6478599: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6478599/pbp.json
# Invalid PBP for game 6478599
# Invalid PBP for game 6478599
# Error fetching PBP via requests for game 6496055: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6496055/pbp.json
# Error fetching PBP via requests for game 6496055: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6496055/pbp.json
# Invalid PBP for game 6496055
# Invalid PBP for game 6496055
# Error fetching PBP via requests for game 6465877: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6465877/pbp.json
# Error fetching PBP via requests for game 6465877: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6465877/pbp.json
# Error fetching PBP via requests for game 6471469: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6471469/pbp.json
# Error fetching PBP via requests for game 6471469: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6471469/pbp.json
# Invalid PBP for game 6471469
# Invalid PBP for game 6471469
# Error fetching PBP via requests for game 6475816: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6475816/pbp.json
# Error fetching PBP via requests for game 6475816: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6475816/pbp.json
# Invalid PBP for game 6475816
# Invalid PBP for game 6475816
# Error fetching PBP via requests for game 6475897: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6475897/pbp.json
# Error fetching PBP via requests for game 6475897: 403 Client Error: Forbidden for url: https://data.ncaa.com/casablanca/game/6475897/pbp.json
# Invalid PBP for game 6475897
# Invalid PBP for game 6475897
# Built 13432 men rows, 15956 women rows
# GKs: 842 men, 1167 women
# Built 13432 men rows, 15956 women rows
# GKs: 842 men, 1167 women

# %%
womens_df.sort_values(by='Points', ascending=False).head(10)
# Out:
#                    Name          Team Gender Division  Matches Played  \
# 7676        Jace Holley      Colorado  women       d1               6
# 7313         Hope Leyba      Colorado  women       d1               6
# 11532   Maddy Theriault     Fairfield  women       d1               6
# 8273   Jordan Frederick         Tulsa  women       d1               6
# 3931     Catherine Rapp      Kentucky  women       d1               6
# 13331       Naomi Clark      Oklahoma  women       d1               6
# 12405       Maya Matesa      Duquesne  women       d1               4
# 8191    Jiselle Daniels          Troy  women       d1               6
# 5343        Ellis Kelly       Memphis  women       d1               5
# 10778       Lilly Yordy  Northern Ky.  women       d1               5
#
#        Minutes Played  Goals  Assists  Shots  Shots On Target  Yellow Cards  \
# 7676              368      7        4     19               11             0
# 7313              391      9        0     20               12             0
# 11532             388      7        2     27               17             0
# 8273              438      6        3     19               10             0
# 3931              347      5        4     15                9             0
# 13331             409      6        2     20               14             0
# 12405             250      7        0     16               10             0
# 8191              502      7        0     21               16             2
# 5343              295      5        3      8                5             0
# 10778             342      3        7     18               10             0
#
#        Red Cards  Saves  Goals Against  Fouls Won Positions Seen  \
# 7676           0      0              0          2              F
# 7313           0      0              0          7              F
# 11532          0      0              0          1              F
# 8273           0      0              0          3              F
# 3931           0      0              0          8              M
# 13331          0      0              0          4              F
# 12405          0      0              0          4              F
# 8191           0      0              0          7              F
# 5343           0      0              0          0              F
# 10778          0      0              0          3              D
#
#       Dominant Position  Points
# 7676            Forward      18
# 7313            Forward      18
# 11532           Forward      16
# 8273            Forward      15
# 3931         Midfielder      14
# 13331           Forward      14
# 12405           Forward      14
# 8191            Forward      14
# 5343            Forward      13
# 10778          Defender      13

# %%
mens_df[mens_df['Team'] == "Bucknell"].sort_values(by='Points', ascending=False).head(30)
# Out:
#                    Name      Team Gender Division  Matches Played  \
# 5902         Jack Lucas  Bucknell    men       d1               4
# 13376      Zane Domsohn  Bucknell    men       d1               4
# 6296      Jakub Samelko  Bucknell    men       d1               4
# 6135       Jacob Thomas  Bucknell    men       d1               4
# 1520      Ben Sheffield  Bucknell    men       d1               4
# 6046   Jackson Sullivan  Bucknell    men       d1               4
# 2777       Cohen Weaver  Bucknell    men       d1               4
# 9754      Nate Coughlin  Bucknell    men       d1               4
# 7845       Kiko Hidalgo  Bucknell    men       d1               4
# 3434       David Krumov  Bucknell    men       d1               4
# 2929    Collin Sullivan  Bucknell    men       d1               4
# 2061       Cade Mcgrath  Bucknell    men       d1               4
# 5864        Jack Heintz  Bucknell    men       d1               1
# 2066      Cade Whitmire  Bucknell    men       d1               4
# 3831        Drew Roskos  Bucknell    men       d1               4
# 7639       Kasper Piela  Bucknell    men       d1               4
# 4992     Gavin Newcombe  Bucknell    men       d1               2
# 9006       Mason Lillis  Bucknell    men       d1               4
# 4786   Freddie Lapworth  Bucknell    men       d1               4
# 10220      Noah Handzel  Bucknell    men       d1               4
# 13108     Winston Oziri  Bucknell    men       d1               3
# 13357        Zain Elder  Bucknell    men       d1               4
# 6703       Jimmy Pombor  Bucknell    men       d1               4
#
#        Minutes Played  Goals  Assists  Shots  Shots On Target  Yellow Cards  \
# 5902              284      3        1     10                6             0
# 13376             238      2        0      6                2             1
# 6296              110      1        0      2                2             1
# 6135              208      1        0      4                1             0
# 1520              303      1        0      2                1             0
# 6046              333      1        0      2                1             1
# 2777              199      0        1      6                4             1
# 9754              132      0        1      1                0             0
# 7845              195      0        1      4                1             0
# 3434              277      0        1      7                3             0
# 2929               71      0        0      0                0             0
# 2061              225      0        0      0                0             1
# 5864                4      0        0      0                0             0
# 2066              145      0        0      0                0             1
# 3831              310      0        0      6                2             0
# 7639               65      0        0      0                0             0
# 4992               29      0        0      0                0             0
# 9006               27      0        0      0                0             0
# 4786              360      0        0      0                0             1
# 10220              80      0        0      0                0             0
# 13108              42      0        0      1                0             0
# 13357              69      0        0      1                1             0
# 6703              291      0        0      0                0             0
#
#        Red Cards  Saves  Goals Against  Fouls Won Positions Seen  \
# 5902           0      0              0          3        D, null
# 13376          0      0              0          4              F
# 6296           0      0              0          1              F
# 6135           0      0              0          1              D
# 1520           0      0              0          1              D
# 6046           0      0              0          4              D
# 2777           0      0              0          2              M
# 9754           0      0              0          1        M, null
# 7845           0      0              0          0        M, null
# 3434           0      0              0          2              M
# 2929           0      0              0          0              D
# 2061           0      0              0          0        D, null
# 5864           0      0              0          0              D
# 2066           0      0              0          3        F, null
# 3831           0      0              0          2              F
# 7639           0      0              0          0        M, null
# 4992           0      0              0          0              D
# 9006           0      0              0          0              F
# 4786           0     21              8          0             GK
# 10220          0      0              0          0        D, null
# 13108          0      0              0          0              F
# 13357          0      0              0          0              M
# 6703           0      0              0          4              M
#
#       Dominant Position  Points
# 5902            Unknown       7
# 13376           Forward       4
# 6296            Forward       2
# 6135           Defender       2
# 1520           Defender       2
# 6046           Defender       2
# 2777         Midfielder       1
# 9754            Unknown       1
# 7845            Unknown       1
# 3434         Midfielder       1
# 2929           Defender       0
# 2061            Unknown       0
# 5864           Defender       0
# 2066            Unknown       0
# 3831            Forward       0
# 7639            Unknown       0
# 4992           Defender       0
# 9006            Forward       0
# 4786         Goalkeeper       0
# 10220           Unknown       0
# 13108           Forward       0
# 13357        Midfielder       0
# 6703         Midfielder       0

# %%
# mens_df.to_csv(rf'2025_data/mens/mensNCAAdata{("").join(END_DATE.split('-')[1:])}')
# womens_df.to_csv(rf'2025_data/womens/womensNCAAdata{("").join(END_DATE.split('-')[1:])}')
